# %% [markdown]
# # 37 Truss Bar

# %%
from Truss_2D import Truss_2D

# %%
nodes = []

for i in range(11):
    for j in range(2):
        nodes.append([i,j])

del nodes[1]
del nodes[-1]
nodes = {key+1: nodes[key] for key in range(20)}

elements=  {1:[1, 3], 2:[2, 3], 3:[4, 3], 4:[3, 5], 5:[4, 5], 6:[6, 5], 7:[5, 7], 8:[6, 7], 9:[8, 7], 10:[7, 9], 
         11:[8, 9], 12:[10, 9], 13:[9, 11], 14:[10, 11], 15:[10, 13], 16:[11, 13], 17:[12, 13], 18:[12, 15], 19:[13, 15], 20:[14, 15], 
         21:[14, 17], 22:[15, 17], 23:[16, 17], 24:[16, 19], 25:[17, 19], 26:[18, 19], 27:[19, 20], 28:[1, 2], 29:[2, 4], 30:[4, 6], 
         31:[6, 8], 32:[8, 10], 33:[10, 12], 34:[12, 14], 35:[14, 16], 36:[16, 18], 37:[18, 20]}

elasticity = {key: 2.11e6 for key in elements}
cross_area = {key: 0.004 for key in elements}
supports = {1:[1,1], 20:[1,1]}
forces = {key: [0,-98.1] for key in range(2,19,2)}

# %%
Truss = Truss_2D(nodes = nodes,
                 elements = elements,
                 supports = supports,
                 forces = forces,
                 elasticity = elasticity,
                 cross_area = cross_area)

# %%
Truss.Draw_Truss_Setup(figure_size=[20,6], length_of_arrow=0.10, width_of_arrow=0.03, offset = 0.015)

# %%
Truss.Solve()
# Out:
# Truss Solved

# %%
Truss.member_forces_
# Out:
# {1: -624.3068,
#  2: 98.0728,
#  3: 485.5532,
#  4: -784.8356,
#  5: -245.2664,
#  6: 346.7996,
#  7: -1030.0176,
#  8: -147.1936,
#  9: 208.0882,
#  10: -1177.2112,
#  11: -49.0364,
#  12: 69.3768,
#  13: -1226.2476,
#  14: 0.0,
#  15: 69.3768,
#  16: -1226.2476,
#  17: -49.0364,
#  18: 208.0882,
#  19: -1177.2112,
#  20: -147.1936,
#  21: 346.7996,
#  22: -1030.0176,
#  23: -245.2664,
#  24: 485.5532,
#  25: -784.8356,
#  26: 98.0728,
#  27: -624.3068,
#  28: -333.5488,
#  29: -333.5488,
#  30: 9.7904,
#  31: 255.0568,
#  32: 402.2504,
#  33: 402.2504,
#  34: 255.0568,
#  35: 9.7904,
#  36: -333.5488,
#  37: -333.5488}

# %%
Truss.Draw_Truss_Displacements(figure_size=[20,6], offset = 0.015, magnification_factor=0.1)

# %%
Truss.displacements_
# Out:
# {1: [0.0, 0.0],
#  2: [-0.03952, -0.65936],
#  3: [0.4998, -0.64774],
#  4: [-0.07904, -1.34164],
#  5: [0.40681, -1.3707],
#  6: [-0.07788, -1.93757],
#  7: [0.28477, -1.95501],
#  8: [-0.04766, -2.33675],
#  9: [0.14529, -2.34256],
#  10: [0.0, -2.50429],
#  11: [-0.0, -2.50429],
#  12: [0.04766, -2.33675],
#  13: [-0.14529, -2.34256],
#  14: [0.07788, -1.93757],
#  15: [-0.28477, -1.95501],
#  16: [0.07904, -1.34164],
#  17: [-0.40681, -1.3707],
#  18: [0.03952, -0.65936],
#  19: [-0.4998, -0.64774],
#  20: [0.0, 0.0]}

# %%
for member in Truss.member_stresses_:
    print(member,": ", round(Truss.member_stresses_[member] / 1000,2))
# Out:
# 1 :  -156.08
# 2 :  24.52
# 3 :  121.39
# 4 :  -196.21
# 5 :  -61.32
# 6 :  86.7
# 7 :  -257.5
# 8 :  -36.8
# 9 :  52.02
# 10 :  -294.3
# 11 :  -12.26
# 12 :  17.34
# 13 :  -306.56
# 14 :  0.0
# 15 :  17.34
# 16 :  -306.56
# 17 :  -12.26
# 18 :  52.02
# 19 :  -294.3
# 20 :  -36.8
# 21 :  86.7
# 22 :  -257.5
# 23 :  -61.32
# 24 :  121.39
# 25 :  -196.21
# 26 :  24.52
# 27 :  -156.08
# 28 :  -83.39
# 29 :  -83.39
# 30 :  2.45
# 31 :  63.76
# 32 :  100.56
# 33 :  100.56
# 34 :  63.76
# 35 :  2.45
# 36 :  -83.39
# 37 :  -83.39
